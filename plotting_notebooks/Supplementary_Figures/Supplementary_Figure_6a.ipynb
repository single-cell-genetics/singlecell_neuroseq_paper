# %%
library(reshape2)
library(ggplot2)
library(dplyr)
library(tidyr)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Attaching package: ‘tidyr’
#
# The following object is masked from ‘package:reshape2’:
#
#     smiths

# %%
mashr_dir = "/hps/nobackup/hipsci/scratch/GTEx/MASHR_INPUT/"

# %%
# list.files(mashr_dir,"MASHR_scInc")

# %%
sign_res = paste0(mashr_dir,"MASHR_scInc_local_false_sign_rate.txt")
mean_beta = paste0(mashr_dir,"MASHR_scInc_posterior_mean.txt")
std_beta = paste0(mashr_dir,"MASHR_scInc_posterior_standard_deviation.txt")
tissue_samplesize = paste0(mashr_dir,"tissueSampleSize_v7.txt")

# %%
##Functions
reorder_cormat <- function(cormat){
  # Use correlation between variables as distance
  dd <- as.dist((1-cormat)/2)
  hc <- hclust(dd,method="complete")
  cormat <-cormat[hc$order, hc$order]
}

# %%
get_lower_tri <- function(cormat){
  cormat[upper.tri(cormat)]<- NA
  return(cormat)
}

# %%
#V6 sc included
lsfrMat = read.delim(sign_res,as.is=T, row.names=1)
posteriorMean = read.delim(mean_beta,as.is=T, row.names=1)

# %%
nrow(lsfrMat)
# Out:
# [1] 7586

# %%
head(lsfrMat)
# Out:
#                                 pool1_13_noddd_D11.FPP pool1_13_noddd_D11.P_FPP
# 1_100088517_C_T-ENSG00000162688 0.8368776270           0.857050284
# 1_100291080_C_T-ENSG00000156875 0.2576963451           0.361795024
# 1_10043142_G_A-ENSG00000162441  0.9999999995           0.999999999
# 1_100518832_T_C-ENSG00000156876 0.0005797932           0.002070684
# 1_100587146_T_C-ENSG00000117620 0.1034974722           0.261161271
# 1_100713300_G_T-ENSG00000137992 0.1297575123           0.100664576
#                                 pool1_13_noddd_D30.Astro pool1_13_noddd_D30.DA
# 1_100088517_C_T-ENSG00000162688 0.857282533              8.704010e-01
# 1_100291080_C_T-ENSG00000156875 0.235901681              4.826098e-01
# 1_10043142_G_A-ENSG00000162441  0.999999999              1.000000e+00
# 1_100518832_T_C-ENSG00000156876 0.001738047              9.004775e-06
# 1_100587146_T_C-ENSG00000117620 0.025866318              5.744199e-02
# 1_100713300_G_T-ENSG00000137992 0.394011654              1.851383e-01
#                                 pool1_13_noddd_D30.Epen1
# 1_100088517_C_T-ENSG00000162688 0.8533494136
# 1_100291080_C_T-ENSG00000156875 0.4732941910
# 1_10043142_G_A-ENSG00000162441  0.9999999994
# 1_100518832_T_C-ENSG00000156876 0.0003010376
# 1_100587146_T_C-ENSG00000117620 0.0254250982
# 1_100713300_G_T-ENSG00000137992 0.4543277478
#                                 pool1_13_noddd_D30.Sert pool1_17_D52.ROT.Astro
# 1_100088517_C_T-ENSG00000162688 0.87024129              0.87510736
# 1_100291080_C_T-ENSG00000156875 0.49548572              0.40272717
# 1_10043142_G_A-ENSG00000162441  1.00000000              1.00000000
# 1_100518832_T_C-ENSG00000156876 0.00337120              0.32795056
# 1_100587146_T_C-ENSG00000117620 0.04367916              0.01434028
# 1_100713300_G_T-ENSG00000137992 0.36982965              0.42507041
#                                 pool1_17_D52.ROT.DA pool1_17_D52.ROT.Epen1
# 1_100088517_C_T-ENSG00000162688 0.871920055         0.8439529486
# 1_100291080_C_T-ENSG00000156875 0.364789088         0.4150558993
# 1_10043142_G_A-ENSG00000162441  0.999999999         0.9999999995
# 1_100518832_T_C-ENSG00000156876 0.002109567         0.0004170323
# 1_100587146_T_C-ENSG00000117620 0.002968737         0.0025483165
# 1_100713300_G_T-ENSG00000137992 0.259739850         0.4391136889
#                                 pool1_17_D52.ROT.Sert ...
# 1_100088517_C_T-ENSG00000162688 0.881624877           ...
# 1_100291080_C_T-ENSG00000156875 0.320247002           ...
# 1_10043142_G_A-ENSG00000162441  0.999999999           ...
# 1_100518832_T_C-ENSG00000156876 0.005741213           ...
# 1_100587146_T_C-ENSG00000117620 0.011471132           ...
# 1_100713300_G_T-ENSG00000137992 0.465247650           ...
#                                 Skin_Not_Sun_Exposed_Suprapubic
# 1_100088517_C_T-ENSG00000162688 8.310251e-01
# 1_100291080_C_T-ENSG00000156875 1.601341e-01
# 1_10043142_G_A-ENSG00000162441  1.000000e+00
# 1_100518832_T_C-ENSG00000156876 2.065891e-16
# 1_100587146_T_C-ENSG00000117620 4.794025e-04
# 1_100713300_G_T-ENSG00000137992 2.870397e-13
#                                 Skin_Sun_Exposed_Lower_leg
# 1_100088517_C_T-ENSG00000162688 8.645379e-01
# 1_100291080_C_T-ENSG00000156875 1.314062e-01
# 1_10043142_G_A-ENSG00000162441  1.000000e+00
# 1_100518832_T_C-ENSG00000156876 1.240428e-17
# 1_100587146_T_C-ENSG00000117620 9.355439e-09
# 1_100713300_G_T-ENSG00000137992 1.573953e-11
#                                 Small_Intestine_Terminal_Ileum Spleen
# 1_100088517_C_T-ENSG00000162688 8.412896e-01                   8.770913e-01
# 1_100291080_C_T-ENSG00000156875 3.778046e-01                   4.624528e-01
# 1_10043142_G_A-ENSG00000162441  1.000000e+00                   1.000000e+00
# 1_100518832_T_C-ENSG00000156876 9.796146e-06                   2.667241e-05
# 1_100587146_T_C-ENSG00000117620 1.717350e-01                   2.106300e-04
# 1_100713300_G_T-ENSG00000137992 5.202815e-12                   3.083679e-12
#                                 Stomach      Testis       Thyroid
# 1_100088517_C_T-ENSG00000162688 8.808719e-01 8.625379e-01 8.227780e-01
# 1_100291080_C_T-ENSG00000156875 3.434180e-01 4.210659e-01 2.338178e-01
# 1_10043142_G_A-ENSG00000162441  1.000000e+00 1.000000e+00 1.000000e+00
# 1_100518832_T_C-ENSG00000156876 3.501420e-07 8.211333e-02 2.513709e-07
# 1_100587146_T_C-ENSG00000117620 5.813853e-05 4.605223e-04 6.660410e-04
# 1_100713300_G_T-ENSG00000137992 2.645489e-13 8.291370e-15 1.424372e-14
#                                 Uterus       Vagina       Whole_Blood
# 1_100088517_C_T-ENSG00000162688 8.339754e-01 8.554107e-01 8.792185e-01
# 1_100291080_C_T-ENSG00000156875 4.075893e-01 3.492515e-01 4.920959e-01
# 1_10043142_G_A-ENSG00000162441  1.000000e+00 1.000000e+00 1.000000e+00
# 1_100518832_T_C-ENSG00000156876 2.391981e-05 2.173801e-03 2.937788e-07
# 1_100587146_T_C-ENSG00000117620 5.790721e-03 1.793607e-01 2.211425e-01
# 1_100713300_G_T-ENSG00000137992 3.910460e-14 2.433825e-11 2.764486e-12

# %%
head(rownames(lsfrMat))
genes = gsub(".*-","",rownames(lsfrMat))
head(genes)
# Out:
# [1] "1_100088517_C_T-ENSG00000162688" "1_100291080_C_T-ENSG00000156875"
# [3] "1_10043142_G_A-ENSG00000162441"  "1_100518832_T_C-ENSG00000156876"
# [5] "1_100587146_T_C-ENSG00000117620" "1_100713300_G_T-ENSG00000137992"
# [1] "ENSG00000162688" "ENSG00000156875" "ENSG00000162441" "ENSG00000156876"
# [5] "ENSG00000117620" "ENSG00000137992"

# %%
# write.csv(genes, "/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/mashr/genes_expressed_in_all_tissues.csv")

# %%
colnames(lsfrMat)
# Out:
#  [1] "pool1_13_noddd_D11.FPP"
#  [2] "pool1_13_noddd_D11.P_FPP"
#  [3] "pool1_13_noddd_D30.Astro"
#  [4] "pool1_13_noddd_D30.DA"
#  [5] "pool1_13_noddd_D30.Epen1"
#  [6] "pool1_13_noddd_D30.Sert"
#  [7] "pool1_17_D52.ROT.Astro"
#  [8] "pool1_17_D52.ROT.DA"
#  [9] "pool1_17_D52.ROT.Epen1"
# [10] "pool1_17_D52.ROT.Sert"
# [11] "pool1_17_D52.Astro"
# [12] "pool1_17_D52.DA"
# [13] "pool1_17_D52.Epen1"
# [14] "pool1_17_D52.Sert"
# [15] "Adipose_Subcutaneous"
# [16] "Adipose_Visceral_Omentum"
# [17] "Adrenal_Gland"
# [18] "Artery_Aorta"
# [19] "Artery_Coronary"
# [20] "Artery_Tibial"
# [21] "Brain_Amygdala"
# [22] "Brain_Anterior_cingulate_cortex_BA24"
# [23] "Brain_Caudate_basal_ganglia"
# [24] "Brain_Cerebellar_Hemisphere"
# [25] "Brain_Cerebellum"
# [26] "Brain_Cortex"
# [27] "Brain_Frontal_Cortex_BA9"
# [28] "Brain_Hippocampus"
# [29] "Brain_Hypothalamus"
# [30] "Brain_Nucleus_accumbens_basal_ganglia"
# [31] "Brain_Putamen_basal_ganglia"
# [32] "Brain_Spinal_cord_cervical_c.1"
# [33] "Brain_Substantia_nigra"
# [34] "Breast_Mammary_Tissue"
# [35] "Cells_EBV.transformed_lymphocytes"
# [36] "Cells_Transformed_fibroblasts"
# [37] "Colon_Sigmoid"
# [38] "Colon_Transverse"
# [39] "Esophagus_Gastroesophageal_Junction"
# [40] "Esophagus_Mucosa"
# [41] "Esophagus_Muscularis"
# [42] "Heart_Atrial_Appendage"
# [43] "Heart_Left_Ventricle"
# [44] "iPSC"
# [45] "Liver"
# [46] "Lung"
# [47] "Minor_Salivary_Gland"
# [48] "Muscle_Skeletal"
# [49] "Nerve_Tibial"
# [50] "Ovary"
# [51] "Pancreas"
# [52] "Pituitary"
# [53] "Prostate"
# [54] "Skin_Not_Sun_Exposed_Suprapubic"
# [55] "Skin_Sun_Exposed_Lower_leg"
# [56] "Small_Intestine_Terminal_Ileum"
# [57] "Spleen"
# [58] "Stomach"
# [59] "Testis"
# [60] "Thyroid"
# [61] "Uterus"
# [62] "Vagina"
# [63] "Whole_Blood"

# %%
# sampleSizeTissues = read.delim(tissue_samplesize,as.is=T, sep=",")
# sampleSizeTissues
# sampleSizeTissues = sampleSizeTissues[match(colnames(lsfrMat),(sampleSizeTissues$tissue)),]
# head(sampleSizeTissues)
# all(sampleSizeTissues$tissue == colnames(lsfrMat))
# sampleSizeTissues[match(colnames(lsfrMat),(sampleSizeTissues$tissue)),]

# %%
ratio = 2
lsfrThreshold = 0.05
any = T
both = F
smallest = F

# %%
sameSignMagnitude = matrix(0, ncol=ncol(lsfrMat), nrow=ncol(lsfrMat))
sameSign = matrix(0, ncol=ncol(lsfrMat), nrow=ncol(lsfrMat))
total = matrix(0, ncol=ncol(lsfrMat), nrow=ncol(lsfrMat))

# %%
cols = grep("_D",colnames(lsfrMat))
length(colnames(lsfrMat)[cols])
# Out:
# [1] 14

# %%
nrow(lsfrMat)
# Out:
# [1] 7586

# %%
options(warn=2)
if(sum(any,both, smallest)==1){
  for(colN in 1:ncol(lsfrMat)){
    for(colM in colN:ncol(lsfrMat)){
      if(any){
        toConsider = unique(c(which(lsfrMat[,colN]<lsfrThreshold),which(lsfrMat[,colM]<lsfrThreshold)))
      } else if(both) {
        toConsider = intersect(which(lsfrMat[,colN]<lsfrThreshold),which(lsfrMat[,colM]<lsfrThreshold))
      } else if(smallest){
        if(sampleSizeTissues$n[colN] > sampleSizeTissues$n[colM]){
          toConsider = which(lsfrMat[,colM]<lsfrThreshold)
        } else {
          toConsider = which(lsfrMat[,colN]<lsfrThreshold)
        }
      }
      total[colN,colM] = length(toConsider)
      total[colM,colN] = total[colN,colM]
      
      tmpInfo = posteriorMean[toConsider,colN]/posteriorMean[toConsider,colM]
      tmpInfo2 = tmpInfo[which(tmpInfo>0)]
      sameSign[colN,colM] = length(tmpInfo2)
      sameSign[colM,colN] = sameSign[colN,colM]
      
      tmpInfo2[which(tmpInfo2<1)] = 1/tmpInfo2[which(tmpInfo2<1)]
      sameSignMagnitude[colN,colM] = length(which(tmpInfo2<=ratio))
      sameSignMagnitude[colM,colN] = sameSignMagnitude[colN,colM]
    }
  }
} else {
  print("Setting issue.")
}

# %%
# options(warn=1)

pairwiseSharingSign = sameSign/total
pairwiseSharing = sameSignMagnitude/total

colnames(pairwiseSharing) = colnames(lsfrMat)
rownames(pairwiseSharing) = colnames(lsfrMat)
colnames(pairwiseSharingSign) = colnames(lsfrMat)
rownames(pairwiseSharingSign) = colnames(lsfrMat)

##Sign only
upper_tri <- get_lower_tri(reorder_cormat(as.matrix(pairwiseSharingSign)))
melted_cormat <- melt(upper_tri, na.rm = TRUE)
head(melted_cormat)
# Out:
#   Var1                              Var2                              value
# 1 Cells_EBV.transformed_lymphocytes Cells_EBV.transformed_lymphocytes 1.0000000
# 2 Whole_Blood                       Cells_EBV.transformed_lymphocytes 0.8502383
# 3 Brain_Cerebellar_Hemisphere       Cells_EBV.transformed_lymphocytes 0.8164971
# 4 Brain_Cerebellum                  Cells_EBV.transformed_lymphocytes 0.8069872
# 5 Brain_Spinal_cord_cervical_c.1    Cells_EBV.transformed_lymphocytes 0.8379447
# 6 Brain_Hypothalamus                Cells_EBV.transformed_lymphocytes 0.8293142

# %%
# install.packages("ggthemes")

# %%
library(ggthemes)

# %%
col_ips = canva_pal("Modern and clean")(4)[2]
col_mesendo = canva_pal("Modern and clean")(4)[4]
col_defendo = canva_pal("Warm tones")(4)[3]

col_FPP = "#aec7e8"
col_P_FPP = "#1f77b4"
col_NB = "#ff7f0e"

col_DA = "#2ca02c"
col_Sert = "#98df8a"
col_Epen1 = "#ff9896"
# col_Astro = "#d62728"
col_Astro = "#9467bd"

# %%
colnames(pairwiseSharingSign)
# Out:
#  [1] "pool1_13_noddd_D11.FPP"
#  [2] "pool1_13_noddd_D11.P_FPP"
#  [3] "pool1_13_noddd_D30.Astro"
#  [4] "pool1_13_noddd_D30.DA"
#  [5] "pool1_13_noddd_D30.Epen1"
#  [6] "pool1_13_noddd_D30.Sert"
#  [7] "pool1_17_D52.ROT.Astro"
#  [8] "pool1_17_D52.ROT.DA"
#  [9] "pool1_17_D52.ROT.Epen1"
# [10] "pool1_17_D52.ROT.Sert"
# [11] "pool1_17_D52.Astro"
# [12] "pool1_17_D52.DA"
# [13] "pool1_17_D52.Epen1"
# [14] "pool1_17_D52.Sert"
# [15] "Adipose_Subcutaneous"
# [16] "Adipose_Visceral_Omentum"
# [17] "Adrenal_Gland"
# [18] "Artery_Aorta"
# [19] "Artery_Coronary"
# [20] "Artery_Tibial"
# [21] "Brain_Amygdala"
# [22] "Brain_Anterior_cingulate_cortex_BA24"
# [23] "Brain_Caudate_basal_ganglia"
# [24] "Brain_Cerebellar_Hemisphere"
# [25] "Brain_Cerebellum"
# [26] "Brain_Cortex"
# [27] "Brain_Frontal_Cortex_BA9"
# [28] "Brain_Hippocampus"
# [29] "Brain_Hypothalamus"
# [30] "Brain_Nucleus_accumbens_basal_ganglia"
# [31] "Brain_Putamen_basal_ganglia"
# [32] "Brain_Spinal_cord_cervical_c.1"
# [33] "Brain_Substantia_nigra"
# [34] "Breast_Mammary_Tissue"
# [35] "Cells_EBV.transformed_lymphocytes"
# [36] "Cells_Transformed_fibroblasts"
# [37] "Colon_Sigmoid"
# [38] "Colon_Transverse"
# [39] "Esophagus_Gastroesophageal_Junction"
# [40] "Esophagus_Mucosa"
# [41] "Esophagus_Muscularis"
# [42] "Heart_Atrial_Appendage"
# [43] "Heart_Left_Ventricle"
# [44] "iPSC"
# [45] "Liver"
# [46] "Lung"
# [47] "Minor_Salivary_Gland"
# [48] "Muscle_Skeletal"
# [49] "Nerve_Tibial"
# [50] "Ovary"
# [51] "Pancreas"
# [52] "Pituitary"
# [53] "Prostate"
# [54] "Skin_Not_Sun_Exposed_Suprapubic"
# [55] "Skin_Sun_Exposed_Lower_leg"
# [56] "Small_Intestine_Terminal_Ileum"
# [57] "Spleen"
# [58] "Stomach"
# [59] "Testis"
# [60] "Thyroid"
# [61] "Uterus"
# [62] "Vagina"
# [63] "Whole_Blood"

# %%
ncol(pairwiseSharingSign)
# Out:
# [1] 63

# %%
 nrow(pairwiseSharingSign)
# Out:
# [1] 63

# %%
pairwiseSharingSign[c(15:20,34:60),c(1:14)]
# Out:
#                                     pool1_13_noddd_D11.FPP
# Adipose_Subcutaneous                0.7610180
# Adipose_Visceral_Omentum            0.7688860
# Adrenal_Gland                       0.7687995
# Artery_Aorta                        0.7697201
# Artery_Coronary                     0.7712748
# Artery_Tibial                       0.7609622
# Breast_Mammary_Tissue               0.7616109
# Cells_EBV.transformed_lymphocytes   0.8056563
# Cells_Transformed_fibroblasts       0.7834535
# Colon_Sigmoid                       0.7663734
# Colon_Transverse                    0.7742782
# Esophagus_Gastroesophageal_Junction 0.7711557
# Esophagus_Mucosa                    0.7614651
# Esophagus_Muscularis                0.7640591
# Heart_Atrial_Appendage              0.7720257
# Heart_Left_Ventricle                0.7779573
# iPSC                                0.7953438
# Liver                               0.7799175
# Lung                                0.7646697
# Minor_Salivary_Gland                0.7857649
# Muscle_Skeletal                     0.7644836
# Nerve_Tibial                        0.7524272
# Ovary                               0.7693390
# Pancreas                            0.7597894
# Pituitary                           0.7761245
# Prostate                            0.7777393
# Skin_Not_Sun_Exposed_Suprapubic     0.7610814
# Skin_Sun_Exposed_Lower_leg          0.7553714
# Small_Intestine_Terminal_Ileum      0.7748888
# Spleen                              0.7665889
# Stomach                             0.7679921
# Testis                              0.7764668
# Thyroid                             0.7553127
#                                     pool1_13_noddd_D11.P_FPP
# Adipose_Subcutaneous                0.7648699
# Adipose_Visceral_Omentum            0.7691078
# Adrenal_Gland                       0.7658520
# Artery_Aorta                        0.7682692
# Artery_Coronary                     0.7727735
# Artery_Tibial                       0.7714373
# Breast_Mammary_Tissue               0.7688572
# Cells_EBV.transformed_lymphocytes   0.8111274
# Cells_Transformed_fibroblasts       0.7842584
# Colon_Sigmoid                       0.7718606
# Colon_Transverse                    0.7713344
# Esophagus_Gastroesophageal_Junction 0.7735849
# Esophagus_Mucosa                    0.7682852
# Esophagus_Muscularis                0.7653190
# Heart_Atrial_Appendage              0.7707930
# Heart_Left_Ventricle                0.7723127
# iPSC                                0.8099106
# Liver                               0.7757074
# Lung                                0.7647965
# Minor_Salivary_Gland                0.7846535
# Muscle_Skeletal                     0.7703002
# Nerve_Tibial                        0.7561494
# Ovary                               0.7701472
# Pancreas                            0.7622032
# Pituitary                           0.7719771
# Prostate                            0.7775078
# Skin_Not_Sun_Exposed_Suprapubic     0.7653509
# Skin_Sun_Exposed_Lower_leg          0.7646334
# Small_Intestine_Terminal_Ileum      0.7739160
# Spleen                              0.7687438
# Stomach                             0.7690539
# Testis                              0.7660726
# Thyroid                             0.7503791
#                                     pool1_13_noddd_D30.Astro
# Adipose_Subcutaneous                0.8032995
# Adipose_Visceral_Omentum            0.8074391
# Adrenal_Gland                       0.8073489
# Artery_Aorta                        0.7954545
# Artery_Coronary                     0.8177981
# Artery_Tibial                       0.7990028
# Breast_Mammary_Tissue               0.8024650
# Cells_EBV.transformed_lymphocytes   0.8047958
# Cells_Transformed_fibroblasts       0.8077170
# Colon_Sigmoid                       0.8048365
# Colon_Transverse                    0.8175307
# Esophagus_Gastroesophageal_Junction 0.8111264
# Esophagus_Mucosa                    0.7959119
# Esophagus_Muscularis                0.7989590
# Heart_Atrial_Appendage              0.8039346
# Heart_Left_Ventricle                0.8105475
# iPSC                                0.7718724
# Liver                               0.8055059
# Lung                                0.7957835
# Minor_Salivary_Gland                0.8208457
# Muscle_Skeletal                     0.7807913
# Nerve_Tibial                        0.7936657
# Ovary                               0.8206262
# Pancreas                            0.7970718
# Pituitary                           0.8174157
# Prostate                            0.8190407
# Skin_Not_Sun_Exposed_Suprapubic     0.7937379
# Skin_Sun_Exposed_Lower_leg          0.7959761
# Small_Intestine_Terminal_Ileum      0.8069360
# Spleen                              0.8000000
# Stomach                             0.8132695
# Testis                              0.8034244
# Thyroid                             0.7912122
#                                     pool1_13_noddd_D30.DA
# Adipose_Subcutaneous                0.7880228
# Adipose_Visceral_Omentum            0.7886581
# Adrenal_Gland                       0.7921676
# Artery_Aorta                        0.7959184
# Artery_Coronary                     0.8035461
# Artery_Tibial                       0.7879925
# Breast_Mammary_Tissue               0.7961295
# Cells_EBV.transformed_lymphocytes   0.7768256
# Cells_Transformed_fibroblasts       0.7855314
# Colon_Sigmoid                       0.8004115
# Colon_Transverse                    0.8002042
# Esophagus_Gastroesophageal_Junction 0.8015791
# Esophagus_Mucosa                    0.7799749
# Esophagus_Muscularis                0.7934923
# Heart_Atrial_Appendage              0.7991266
# Heart_Left_Ventricle                0.7940379
# iPSC                                0.7565217
# Liver                               0.7836383
# Lung                                0.7887413
# Minor_Salivary_Gland                0.8041045
# Muscle_Skeletal                     0.7741100
# Nerve_Tibial                        0.7885518
# Ovary                               0.7994821
# Pancreas                            0.7840793
# Pituitary                           0.8109560
# Prostate                            0.8088235
# Skin_Not_Sun_Exposed_Suprapubic     0.7850226
# Skin_Sun_Exposed_Lower_leg          0.7896725
# Small_Intestine_Terminal_Ileum      0.7989228
# Spleen                              0.7792072
# Stomach                             0.8036326
# Testis                              0.7828084
# Thyroid                             0.7860494
#                                     pool1_13_noddd_D30.Epen1
# Adipose_Subcutaneous                0.7940051
# Adipose_Visceral_Omentum            0.8033876
# Adrenal_Gland                       0.8067867
# Artery_Aorta                        0.7931714
# Artery_Coronary                     0.8140276
# Artery_Tibial                       0.7959438
# Breast_Mammary_Tissue               0.8045822
# Cells_EBV.transformed_lymphocytes   0.7846619
# Cells_Transformed_fibroblasts       0.7951031
# Colon_Sigmoid                       0.8021262
# Colon_Transverse                    0.8100655
# Esophagus_Gastroesophageal_Junction 0.8017987
# Esophagus_Mucosa                    0.7806879
# Esophagus_Muscularis                0.7945964
# Heart_Atrial_Appendage              0.8098283
# Heart_Left_Ventricle                0.8075101
# iPSC                                0.7624490
# Liver                               0.8074534
# Lung                                0.7996830
# Minor_Salivary_Gland                0.8190404
# Muscle_Skeletal                     0.7816947
# Nerve_Tibial                        0.7957327
# Ovary                               0.8131086
# Pancreas                            0.7984869
# Pituitary                           0.8217716
# Prostate                            0.8145280
# Skin_Not_Sun_Exposed_Suprapubic     0.7941842
# Skin_Sun_Exposed_Lower_leg          0.7873146
# Small_Intestine_Terminal_Ileum      0.8069986
# Spleen                              0.7959540
# Stomach                             0.8092624
# Testis                              0.8005319
# Thyroid                             0.7902164
#                                     pool1_13_noddd_D30.Sert
# Adipose_Subcutaneous                0.8054140
# Adipose_Visceral_Omentum            0.8110964
# Adrenal_Gland                       0.8087526
# Artery_Aorta                        0.8133510
# Artery_Coronary                     0.8275616
# Artery_Tibial                       0.8096875
# Breast_Mammary_Tissue               0.8138047
# Cells_EBV.transformed_lymphocytes   0.7979646
# Cells_Transformed_fibroblasts       0.8085723
# Colon_Sigmoid                       0.8183060
# Colon_Transverse                    0.8181818
# Esophagus_Gastroesophageal_Junction 0.8189329
# Esophagus_Mucosa                    0.7984887
# Esophagus_Muscularis                0.8106528
# Heart_Atrial_Appendage              0.8095877
# Heart_Left_Ventricle                0.8109838
# iPSC                                0.7752319
# Liver                               0.8108893
# Lung                                0.8065532
# Minor_Salivary_Gland                0.8231293
# Muscle_Skeletal                     0.7941081
# Nerve_Tibial                        0.7994980
# Ovary                               0.8202541
# Pancreas                            0.8060315
# Pituitary                           0.8304659
# Prostate                            0.8272290
# Skin_Not_Sun_Exposed_Suprapubic     0.8097861
# Skin_Sun_Exposed_Lower_leg          0.8044994
# Small_Intestine_Terminal_Ileum      0.8181490
# Spleen                              0.8066992
# Stomach                             0.8203634
# Testis                              0.8077560
# Thyroid                             0.8025039
#                                     pool1_17_D52.ROT.Astro pool1_17_D52.ROT.DA
# Adipose_Subcutaneous                0.7992878              0.7889789
# Adipose_Visceral_Omentum            0.8043405              0.7881471
# Adrenal_Gland                       0.8052408              0.7941595
# Artery_Aorta                        0.7993266              0.7887610
# Artery_Coronary                     0.8087591              0.8071271
# Artery_Tibial                       0.7949937              0.7892902
# Breast_Mammary_Tissue               0.7984895              0.7904006
# Cells_EBV.transformed_lymphocytes   0.7839410              0.7747535
# Cells_Transformed_fibroblasts       0.7996732              0.7899769
# Colon_Sigmoid                       0.8012596              0.7951426
# Colon_Transverse                    0.8105557              0.7966936
# Esophagus_Gastroesophageal_Junction 0.8035903              0.7956645
# Esophagus_Mucosa                    0.7763916              0.7744216
# Esophagus_Muscularis                0.7922164              0.7893864
# Heart_Atrial_Appendage              0.8012337              0.7960389
# Heart_Left_Ventricle                0.8030981              0.7941484
# iPSC                                0.7574760              0.7537272
# Liver                               0.7991788              0.7824284
# Lung                                0.7974968              0.7871239
# Minor_Salivary_Gland                0.8083204              0.8026625
# Muscle_Skeletal                     0.7822660              0.7738610
# Nerve_Tibial                        0.7959249              0.7866965
# Ovary                               0.8100537              0.8020226
# Pancreas                            0.7873303              0.7765285
# Pituitary                           0.8115836              0.8090137
# Prostate                            0.8088069              0.8007619
# Skin_Not_Sun_Exposed_Suprapubic     0.7818660              0.7861656
# Skin_Sun_Exposed_Lower_leg          0.7823043              0.7852564
# Small_Intestine_Terminal_Ileum      0.8008145              0.7927693
# Spleen                              0.7883655              0.7826399
# Stomach                             0.8089060              0.7968916
# Testis                              0.7855462              0.7813779
# Thyroid                             0.7844635              0.7821623
#                                     pool1_17_D52.ROT.Epen1
# Adipose_Subcutaneous                0.7980154
# Adipose_Visceral_Omentum            0.8112330
# Adrenal_Gland                       0.8115038
# Artery_Aorta                        0.7963024
# Artery_Coronary                     0.8126338
# Artery_Tibial                       0.7975078
# Breast_Mammary_Tissue               0.8122683
# Cells_EBV.transformed_lymphocytes   0.7909540
# Cells_Transformed_fibroblasts       0.8051613
# Colon_Sigmoid                       0.8080877
# Colon_Transverse                    0.8128028
# Esophagus_Gastroesophageal_Junction 0.8018672
# Esophagus_Mucosa                    0.7842520
# Esophagus_Muscularis                0.7978551
# Heart_Atrial_Appendage              0.8052828
# Heart_Left_Ventricle                0.8043552
# iPSC                                0.7595109
# Liver                               0.8057395
# Lung                                0.8054054
# Minor_Salivary_Gland                0.8218608
# Muscle_Skeletal                     0.7937074
# Nerve_Tibial                        0.7921507
# Ovary                               0.8176713
# Pancreas                            0.7932215
# Pituitary                           0.8242034
# Prostate                            0.8245353
# Skin_Not_Sun_Exposed_Suprapubic     0.7931929
# Skin_Sun_Exposed_Lower_leg          0.7920228
# Small_Intestine_Terminal_Ileum      0.8074827
# Spleen                              0.7936453
# Stomach                             0.8117040
# Testis                              0.7905742
# Thyroid                             0.7926906
#                                     pool1_17_D52.ROT.Sert pool1_17_D52.Astro
# Adipose_Subcutaneous                0.7898251             0.8031623
# Adipose_Visceral_Omentum            0.7970297             0.8143389
# Adrenal_Gland                       0.7960865             0.8121684
# Artery_Aorta                        0.7931034             0.8059100
# Artery_Coronary                     0.8033192             0.8250540
# Artery_Tibial                       0.7942643             0.8021458
# Breast_Mammary_Tissue               0.7973289             0.8138498
# Cells_EBV.transformed_lymphocytes   0.7826087             0.7968932
# Cells_Transformed_fibroblasts       0.7974400             0.8178851
# Colon_Sigmoid                       0.7917091             0.8160999
# Colon_Transverse                    0.8047700             0.8236732
# Esophagus_Gastroesophageal_Junction 0.7955403             0.8166550
# Esophagus_Mucosa                    0.7809644             0.7964800
# Esophagus_Muscularis                0.7905318             0.8122328
# Heart_Atrial_Appendage              0.7901816             0.8203367
# Heart_Left_Ventricle                0.7980346             0.8140826
# iPSC                                0.7678280             0.7749108
# Liver                               0.7961373             0.8054215
# Lung                                0.7862330             0.8050112
# Minor_Salivary_Gland                0.8195122             0.8225806
# Muscle_Skeletal                     0.7845555             0.7957166
# Nerve_Tibial                        0.7834633             0.7994940
# Ovary                               0.7984439             0.8180084
# Pancreas                            0.7884157             0.7994429
# Pituitary                           0.8115685             0.8240876
# Prostate                            0.8102056             0.8200301
# Skin_Not_Sun_Exposed_Suprapubic     0.7913692             0.7940503
# Skin_Sun_Exposed_Lower_leg          0.7870662             0.7908975
# Small_Intestine_Terminal_Ileum      0.7914878             0.8113069
# Spleen                              0.7803949             0.8036788
# Stomach                             0.8032115             0.8164403
# Testis                              0.7764590             0.7932773
# Thyroid                             0.7801751             0.7946117
#                                     pool1_17_D52.DA pool1_17_D52.Epen1
# Adipose_Subcutaneous                0.7798282       0.7998111
# Adipose_Visceral_Omentum            0.7861176       0.8075916
# Adrenal_Gland                       0.7865517       0.8088285
# Artery_Aorta                        0.7889514       0.8016796
# Artery_Coronary                     0.7980156       0.8113597
# Artery_Tibial                       0.7862069       0.7982833
# Breast_Mammary_Tissue               0.7892452       0.8094765
# Cells_EBV.transformed_lymphocytes   0.7719430       0.7846608
# Cells_Transformed_fibroblasts       0.7920951       0.8019078
# Colon_Sigmoid                       0.7920521       0.8047138
# Colon_Transverse                    0.7925623       0.8157100
# Esophagus_Gastroesophageal_Junction 0.7980041       0.8060155
# Esophagus_Mucosa                    0.7752845       0.7838258
# Esophagus_Muscularis                0.7849741       0.7983974
# Heart_Atrial_Appendage              0.7989882       0.8044693
# Heart_Left_Ventricle                0.7955239       0.8033113
# iPSC                                0.7595316       0.7601297
# Liver                               0.7748918       0.8001417
# Lung                                0.7835279       0.8019894
# Minor_Salivary_Gland                0.8004510       0.8200073
# Muscle_Skeletal                     0.7709552       0.7791587
# Nerve_Tibial                        0.7870603       0.7908557
# Ovary                               0.7983600       0.8141978
# Pancreas                            0.7795168       0.7942068
# Pituitary                           0.8109843       0.8232429
# Prostate                            0.8031641       0.8301547
# Skin_Not_Sun_Exposed_Suprapubic     0.7856447       0.7964912
# Skin_Sun_Exposed_Lower_leg          0.7748428       0.7914339
# Small_Intestine_Terminal_Ileum      0.7854077       0.8091737
# Spleen                              0.7872045       0.7985612
# Stomach                             0.7966621       0.8055275
# Testis                              0.7774481       0.7977273
# Thyroid                             0.7811132       0.8018692
#                                     pool1_17_D52.Sert
# Adipose_Subcutaneous                0.7897870
# Adipose_Visceral_Omentum            0.7982341
# Adrenal_Gland                       0.8101868
# Artery_Aorta                        0.7923479
# Artery_Coronary                     0.8058152
# Artery_Tibial                       0.7909483
# Breast_Mammary_Tissue               0.8007942
# Cells_EBV.transformed_lymphocytes   0.7827035
# Cells_Transformed_fibroblasts       0.7981593
# Colon_Sigmoid                       0.8016140
# Colon_Transverse                    0.8135707
# Esophagus_Gastroesophageal_Junction 0.8020974
# Esophagus_Mucosa                    0.7896209
# Esophagus_Muscularis                0.7958333
# Heart_Atrial_Appendage              0.8014488
# Heart_Left_Ventricle                0.7990685
# iPSC                                0.7731206
# Liver                               0.8019001
# Lung                                0.7911985
# Minor_Salivary_Gland                0.8218876
# Muscle_Skeletal                     0.7802619
# Nerve_Tibial                        0.7861343
# Ovary                               0.8059863
# Pancreas                            0.7990576
# Pituitary                           0.8268353
# Prostate                            0.8169771
# Skin_Not_Sun_Exposed_Suprapubic     0.7931034
# Skin_Sun_Exposed_Lower_leg          0.7903876
# Small_Intestine_Terminal_Ileum      0.8025856
# Spleen                              0.7941576
# Stomach                             0.8119112
# Testis                              0.7820305
# Thyroid                             0.7926110

# %%
mat_to_plot1 = pairwiseSharing[c(21:33),c(1:14)]
mat_to_plot2 = pairwiseSharing[c(15:20,34:63),c(1:14)]
# mat_to_plot1 = pairwiseSharingSign[c(21:33),c(1:14)]
# mat_to_plot2 = pairwiseSharingSign[c(15:20,34:63),c(1:14)]

# %%
nrow(mat_to_plot2)
# Out:
# [1] 36

# %%
df1 = as.data.frame(mat_to_plot1) %>% gather(key="CellType", value="Sharing")
df1$Tissue = "Brain"
df2 = as.data.frame(mat_to_plot2) %>% gather(key="CellType", value="Sharing")
df2$Tissue = "Other"
df = rbind(df1,df2)
df$comparison = paste0(df$CellType,"-",df$Tissue)
head(df,2)
# Out:
#   CellType               Sharing   Tissue comparison
# 1 pool1_13_noddd_D11.FPP 0.4106948 Brain  pool1_13_noddd_D11.FPP-Brain
# 2 pool1_13_noddd_D11.FPP 0.4015498 Brain  pool1_13_noddd_D11.FPP-Brain

# %%
options(repr.plot.width=4, repr.plot.height=4)
ggplot(df, aes(x = Tissue, y = Sharing, colour = Tissue)) + geom_violin() + geom_boxplot(width = 0.3) + 
    scale_colour_manual(values = c("darkgoldenrod3","black")) + theme_classic()
# Out:
# plot without title

# %%
fig_dir = "/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/figures/extended_figures/"

pdf(paste0(fig_dir,"Supp_Fig_6a.pdf"), width=4, height=4)
ggplot(df, aes(x = Tissue, y = Sharing, colour = Tissue)) + geom_violin() + geom_boxplot(width = 0.3) + 
    scale_colour_manual(values = c("darkgoldenrod3","black")) + theme_classic()
dev.off()
# Out:
# png
#   2

# %%
options(repr.plot.width=12, repr.plot.height=8)
ggplot(df,aes(x=comparison, y=Sharing, fill=CellType, col = Tissue)) +  
    geom_violin() + 
    geom_boxplot(width = 0.3) + 
                scale_colour_manual(values = c("darkgoldenrod3","black"))+
                scale_fill_manual(values = c(
#                     "gold","brown",
#                     col_ips,col_ips,
                            col_FPP,col_P_FPP,
                            col_FPP,col_DA,col_Epen1,col_Sert,
                            col_Astro,col_Astro,col_DA,col_DA,
                            col_Epen1,col_Epen1,col_Sert,col_Sert
                            ))+ 
theme_classic() + xlab("") + 
theme(legend.position = "none", axis.text.x = element_text(angle = 90, hjust = 1, size = 11))
# Out:
# plot without title
